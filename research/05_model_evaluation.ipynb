# %%
import os

# %%
# %pwd
# Out:
# '/Users/rajat.sharma/MyData/Personal/InterviewKickstarter/MLSwitchup/MLOps/ModelDeploymentAndInference2/End_to_end_MLOPS_project'

# %%
import dagshub
dagshub.init(repo_owner='rajatsharma01', repo_name='End_to_end_MLOPS_project', mlflow=True)

import mlflow
with mlflow.start_run():
  mlflow.log_param('parameter name', 'value')
  mlflow.log_metric('metric name', 1)
# Out:
#                                        ❗❗❗ AUTHORIZATION REQUIRED ❗❗❗
# Open the following link in your browser to authorize the client:
# https://dagshub.com/login/oauth/authorize?state=769e9e74-d366-4ccf-a673-8adddf1ab291&client_id=32b60ba385aa7cecf24046d8195a71c07dd345d9657977863b52e7748e0f0f28&middleman_request_id=6aa007e31efceb1efdb3b68dab0ad9b5fa1a8efc4f1a703243f4e058a98323b5
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/MyData/Personal/InterviewKickstarter/MLSwitchup/MLOps/ModelDeploymentAndInference2/End_to_end_MLOPS_project/env/lib/python3.8/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# ...
